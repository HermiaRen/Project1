# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# %%
#import CSV 
combined_data= pd.read_csv("merged_videos.csv")
combined_data.head()
# Out:
#                                           Video Name  \
# 0         BARU! Keju Cheddar Anchor dari New Zealand
# 1  CHHAKKA PANJA (Full Movie) - Superhit Nepali F...
# 2  DREAMS (Full Movie) Anmol KC | Samragyee RL Sh...
# 3  Bhairav || à¤­à¥à¤°à¤¬ || Nepali Action Movie...
# 4  å¥³å­©ä¸çµæ¢¯é­ç·å­©æ¶æå
# ³åï¼ä»çµæ...
#
#                  Channel ID     Views   Likes  Dislikes  Comments  \
# 0  UCfDpWxtKc_PBOXr7gPLXLrQ  24928443      32         0         5
# 1  UCrzyJYtjLOTfnUur8hsr7ow  22639285  120531         0      7473
# 2  UCrzyJYtjLOTfnUur8hsr7ow  16144028  125884         0      6735
# 3  UCNR1KcWXj7zpWQFJtU3ddYg  11888301   92724         0      3836
# 4  UCUbw50S9E4dRDq8whoUGtsA   8537098   85433         0      2488
#
#       Time of Uploading          Category
# 0  2023-05-16T03:21:41Z    People & Blogs
# 1  2017-01-13T01:37:07Z  Film & Animation
# 2  2016-09-09T16:55:30Z  Film & Animation
# 3  2016-06-15T18:15:01Z  Film & Animation
# 4  2023-06-17T23:00:24Z    People & Blogs

# %%
cleaned_df = combined_data.drop_duplicates(subset=['Category'])
cleaned_df
# Out:
#                                             Video Name  \
# 0           BARU! Keju Cheddar Anchor dari New Zealand
# 1    CHHAKKA PANJA (Full Movie) - Superhit Nepali F...
# 5    The Grand Old Duke of York in HD | Nursery Rhy...
# 12   Meray Hi Rehna Episode 58 | 31st July 2023 (En...
# 14   Top 10 Hardest Punchers In Boxing (circa 2020)...
# 16   din bhar ki khabar | news of the day, hindi ne...
# 17     ÙØ¶ÙØª 24 Ø³Ø§Ø¹Ù Ø¹ÙÙ Ø§ÙØ±Ø§ÙØ¹Ù ð­
# 19                            FORTNITE UNVAULTED BOWS!
# 24   Deadly Ambush - Marine Disobeys Orders &amp; I...
# 27                           Orca Wardrobe Malfunction
# 28   [#ëí¼ìì°ë¤] ì¤ë ì±ë¹ì´ ë¨¹ì ê²...
# 32   EXPOSING SCAMMER AFTER $82,670 STOLEN FROM DRE...
# 45   Amsterdam(Europe) Mein Ek Galti Ki Wajah Se â...
# 88   Motorola Edge 30 Ultra Unboxing and First Impr...
# 354  TÆ° Lá»nh TQLC Nga á» Kherson cÃ³ thá» ÄÃ£...
#
#                    Channel ID     Views   Likes  Dislikes  Comments  \
# 0    UCfDpWxtKc_PBOXr7gPLXLrQ  24928443      32         0         5
# 1    UCrzyJYtjLOTfnUur8hsr7ow  22639285  120531         0      7473
# 5    UCBfYm4CdlUBDZd83SVIZM6Q   7822151   12428         0         0
# 12   UC4JCksJF76g_MdzPVBJoC3Q   1659355   23823         0       578
# 14   UCSAKHhhVMjKZxApVg5nfuYw   1489336   10560         0       966
# 16   UCBbpLKJLhIbDd_wX4ubU_Cw   1138814   16051         0       442
# 17   UCmWV4bvAO4vUQtRZayT1usw   1137532   83974         0     10947
# 19   UC-sjC5fKKsrpcZRJwlZJzZQ   1060774   91491         0      1705
# 24   UCl3SuH2Ue044b7ACX1syk4A    615654   16549         0      1245
# 27   UC-MQX5lkRIkpnyqLnS92obg    490751     606         0         9
# 28   UCiwQRG2sCcfjKkgxMEdJGPg    486912    3165         0       274
# 32   UCj_ARBxhCoF5JxUItcEUs7Q    436144   29006         0      2229
# 45   UCYUq_wB2ieVws9K4kmjWcaQ    387849   34265         0      1245
# 88   UC-8NKfvYQoZLYcwdU_gr4Cg    151969    1769         0       109
# 354  UCdioDuMh5_afhGJTAkbQjdQ    203657       0         0         0
#
#         Time of Uploading               Category
# 0    2023-05-16T03:21:41Z         People & Blogs
# 1    2017-01-13T01:37:07Z       Film & Animation
# 5    2014-04-11T07:43:01Z                  Music
# 12   2023-07-31T17:21:08Z          Entertainment
# 14   2020-03-26T18:31:29Z                 Sports
# 16   2023-07-31T14:03:27Z        News & Politics
# 17   2023-07-31T16:10:20Z          Howto & Style
# 19   2022-02-22T15:31:55Z                 Gaming
# 24   2021-11-19T19:57:03Z              Education
# 27   2023-03-13T13:13:09Z         Pets & Animals
# 28   2023-07-31T07:29:12Z                 Comedy
# 32   2023-07-31T13:00:44Z       Autos & Vehicles
# 45   2023-08-01T03:30:26Z        Travel & Events
# 88   2022-09-08T19:17:23Z   Science & Technology
# 354  2023-02-03T21:00:22Z  Nonprofits & Activism

# %%
total_views=len(combined_data["Views"].unique())
print(total_views)
total_comments= len(combined_data["Comments"])
total_comments
# Out:
# 433
# 433

# %%
category_df= cleaned_df.groupby( "Category")
category_df.head()
# Out:
#                                             Video Name  \
# 0           BARU! Keju Cheddar Anchor dari New Zealand
# 1    CHHAKKA PANJA (Full Movie) - Superhit Nepali F...
# 5    The Grand Old Duke of York in HD | Nursery Rhy...
# 12   Meray Hi Rehna Episode 58 | 31st July 2023 (En...
# 14   Top 10 Hardest Punchers In Boxing (circa 2020)...
# 16   din bhar ki khabar | news of the day, hindi ne...
# 17     ÙØ¶ÙØª 24 Ø³Ø§Ø¹Ù Ø¹ÙÙ Ø§ÙØ±Ø§ÙØ¹Ù ð­
# 19                            FORTNITE UNVAULTED BOWS!
# 24   Deadly Ambush - Marine Disobeys Orders &amp; I...
# 27                           Orca Wardrobe Malfunction
# 28   [#ëí¼ìì°ë¤] ì¤ë ì±ë¹ì´ ë¨¹ì ê²...
# 32   EXPOSING SCAMMER AFTER $82,670 STOLEN FROM DRE...
# 45   Amsterdam(Europe) Mein Ek Galti Ki Wajah Se â...
# 88   Motorola Edge 30 Ultra Unboxing and First Impr...
# 354  TÆ° Lá»nh TQLC Nga á» Kherson cÃ³ thá» ÄÃ£...
#
#                    Channel ID     Views   Likes  Dislikes  Comments  \
# 0    UCfDpWxtKc_PBOXr7gPLXLrQ  24928443      32         0         5
# 1    UCrzyJYtjLOTfnUur8hsr7ow  22639285  120531         0      7473
# 5    UCBfYm4CdlUBDZd83SVIZM6Q   7822151   12428         0         0
# 12   UC4JCksJF76g_MdzPVBJoC3Q   1659355   23823         0       578
# 14   UCSAKHhhVMjKZxApVg5nfuYw   1489336   10560         0       966
# 16   UCBbpLKJLhIbDd_wX4ubU_Cw   1138814   16051         0       442
# 17   UCmWV4bvAO4vUQtRZayT1usw   1137532   83974         0     10947
# 19   UC-sjC5fKKsrpcZRJwlZJzZQ   1060774   91491         0      1705
# 24   UCl3SuH2Ue044b7ACX1syk4A    615654   16549         0      1245
# 27   UC-MQX5lkRIkpnyqLnS92obg    490751     606         0         9
# 28   UCiwQRG2sCcfjKkgxMEdJGPg    486912    3165         0       274
# 32   UCj_ARBxhCoF5JxUItcEUs7Q    436144   29006         0      2229
# 45   UCYUq_wB2ieVws9K4kmjWcaQ    387849   34265         0      1245
# 88   UC-8NKfvYQoZLYcwdU_gr4Cg    151969    1769         0       109
# 354  UCdioDuMh5_afhGJTAkbQjdQ    203657       0         0         0
#
#         Time of Uploading               Category
# 0    2023-05-16T03:21:41Z         People & Blogs
# 1    2017-01-13T01:37:07Z       Film & Animation
# 5    2014-04-11T07:43:01Z                  Music
# 12   2023-07-31T17:21:08Z          Entertainment
# 14   2020-03-26T18:31:29Z                 Sports
# 16   2023-07-31T14:03:27Z        News & Politics
# 17   2023-07-31T16:10:20Z          Howto & Style
# 19   2022-02-22T15:31:55Z                 Gaming
# 24   2021-11-19T19:57:03Z              Education
# 27   2023-03-13T13:13:09Z         Pets & Animals
# 28   2023-07-31T07:29:12Z                 Comedy
# 32   2023-07-31T13:00:44Z       Autos & Vehicles
# 45   2023-08-01T03:30:26Z        Travel & Events
# 88   2022-09-08T19:17:23Z   Science & Technology
# 354  2023-02-03T21:00:22Z  Nonprofits & Activism

# %%
#group by comments vs views

Comments = category_df["Comments"].sum()

Views = category_df["Views"].mean()

likes = category_df["Likes"].mean()


# Assemble the resulting series into a single summary DataFrame.
Q1_df= pd.DataFrame({"Comments":Comments, "Views":Views, "Likes": likes})

Q1_df
# Out:
#                        Comments       Views     Likes
# Category
# Autos & Vehicles           2229    436144.0   29006.0
# Comedy                      274    486912.0    3165.0
# Education                  1245    615654.0   16549.0
# Entertainment               578   1659355.0   23823.0
# Film & Animation           7473  22639285.0  120531.0
# Gaming                     1705   1060774.0   91491.0
# Howto & Style             10947   1137532.0   83974.0
# Music                         0   7822151.0   12428.0
# News & Politics             442   1138814.0   16051.0
# Nonprofits & Activism         0    203657.0       0.0
# People & Blogs                5  24928443.0      32.0
# Pets & Animals                9    490751.0     606.0
# Science & Technology        109    151969.0    1769.0
# Sports                      966   1489336.0   10560.0
# Travel & Events            1245    387849.0   34265.0

# %%
#plot Bar chat

comments_df= Q1_df.groupby(["Category"]).mean()["Comments"]

plot_bar_comments = comments_df.plot(kind = "bar",figsize=(10,8), color='g')


plot_bar_views.set_ylabel("Comments")
plot_bar_views.set_xlabel("Category")
plt.show()

plt.tight_layout()
plt.savefig("Bar plot comments")

# %%
#Likes_df= Q1_df.groupby(["Category"]).mean()["Comments"]

#plot_bar_comments =Likes_df.plot(kind = "bar",figsize=(12,10), color='b',)


#plot_bar_views.set_ylabel("Likes")
#plot_bar_views.set_xlabel("Category")
#plt.show()
