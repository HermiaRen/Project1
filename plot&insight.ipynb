# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import scipy.stats as st
from scipy import stats

# %%
file = pd.read_csv("Resources/merged_videos.csv", encoding='utf-8')
file.head()
# Out:
#                                           Video Name  \
# 0         BARU! Keju Cheddar Anchor dari New Zealand
# 1  CHHAKKA PANJA (Full Movie) - Superhit Nepali F...
# 2  DREAMS (Full Movie) Anmol KC | Samragyee RL Sh...
# 3  Bhairav || à¤­à¥à¤°à¤¬ || Nepali Action Movie...
# 4  å¥³å­©ä¸çµæ¢¯é­ç·å­©æ¶æå
# ³åï¼ä»çµæ...
#
#                  Channel ID     Views   Likes  Dislikes  Comments  \
# 0  UCfDpWxtKc_PBOXr7gPLXLrQ  24928443      32         0         5
# 1  UCrzyJYtjLOTfnUur8hsr7ow  22639285  120531         0      7473
# 2  UCrzyJYtjLOTfnUur8hsr7ow  16144028  125884         0      6735
# 3  UCNR1KcWXj7zpWQFJtU3ddYg  11888301   92724         0      3836
# 4  UCUbw50S9E4dRDq8whoUGtsA   8537098   85433         0      2488
#
#       Time of Uploading          Category
# 0  2023-05-16T03:21:41Z    People & Blogs
# 1  2017-01-13T01:37:07Z  Film & Animation
# 2  2016-09-09T16:55:30Z  Film & Animation
# 3  2016-06-15T18:15:01Z  Film & Animation
# 4  2023-06-17T23:00:24Z    People & Blogs

# %%
# Convert Views and Likes columns to millions
million_factor = 1e-6  
thousand_factor = 1e-3

# %%
file["Views (Millions)"] = file["Views"] * million_factor
file["Likes (Thousands)"] = file["Likes"] * thousand_factor
# Sample data
x = file["Likes (Thousands)"]
y = file["Views (Millions)"]
# Perform linear regression
slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)
#Create Scatter Plots
plt.scatter(x, y, marker="o", color="blue", edgecolors = "black" )
plt.xlabel("Amount of Likes(thousand)")
plt.ylabel("Amount of Views(million)")
plt.title("Video Likes vs. Views")
# Plot the regression line
regression_line = slope * x + intercept
plt.plot(x, regression_line, color="red", label="Regression Line")
# Display the linear regression equation and correlation coefficient on the plot
equation = f"y = {slope:.2f}x + {intercept:.2f}"
correlation = f"Correlation: {r_value:.2f}"
plt.text(0.1, 0.9, equation, transform=plt.gca().transAxes)
plt.text(0.1, 0.85, correlation, transform=plt.gca().transAxes)
plt.savefig("output/1.png")
plt.show()

# %%
file["Comments (Thousands)"] = file["Comments"] * thousand_factor
file["Likes (Thousands)"] = file["Likes"] * thousand_factor
#Sample data
x = file["Likes (Thousands)"]
y = file["Comments (Thousands)"]
# Perform linear regression
slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)
#Create Scatter Plots
plt.scatter(x, y, marker="o", color="blue", edgecolors = "black" )
plt.xlabel("Amount of Likes(thousand)")
plt.ylabel("Amount of Comments(thousand)")
plt.title("Video Likes vs. Comments")
# Plot the regression line
regression_line = slope * x + intercept
plt.plot(x, regression_line, color="red", label="Regression Line")
# Display the linear regression equation and correlation coefficient on the plot
equation = f"y = {slope:.2f}x + {intercept:.2f}"
correlation = f"Correlation: {r_value:.2f}"
plt.text(0.1, 0.9, equation, transform=plt.gca().transAxes)
plt.text(0.1, 0.85, correlation, transform=plt.gca().transAxes)
plt.savefig("output/2.png")
plt.show()

# %%
#Sample data
x = file["Views (Millions)"]
y = file["Comments (Thousands)"]
# Perform linear regression
slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)
#Create Scatter Plots
plt.scatter(x, y, marker="o", color="blue", edgecolors = "black" )
plt.xlabel("Amount of Views(million)")
plt.ylabel("Amount of Comments(thousand)")
plt.title("Video Views vs. Comments")
# Plot the regression line
regression_line = slope * x + intercept
plt.plot(x, regression_line, color="red", label="Regression Line")
# Display the linear regression equation and correlation coefficient on the plot
equation = f"y = {slope:.2f}x + {intercept:.2f}"
correlation = f"Correlation: {r_value:.2f}"
plt.text(0.1, 0.9, equation, transform=plt.gca().transAxes)
plt.text(0.1, 0.85, correlation, transform=plt.gca().transAxes)
plt.savefig("output/3.png")
plt.show()

# %%
category_file = file.groupby(["Category"])
category_file.head()
# Out:
#                                             Video Name  \
# 0           BARU! Keju Cheddar Anchor dari New Zealand
# 1    CHHAKKA PANJA (Full Movie) - Superhit Nepali F...
# 2    DREAMS (Full Movie) Anmol KC | Samragyee RL Sh...
# 3    Bhairav || à¤­à¥à¤°à¤¬ || Nepali Action Movie...
# 4    å¥³å­©ä¸çµæ¢¯é­ç·å­©æ¶æå
# ³åï¼ä»çµæ...
# ..                                                 ...
# 296         Butterfly Wonderland | Uniquely Scottsdale
# 325       Water Mission - Tommy&#39;s Express Car Wash
# 346  Here&#39;s Why Toyota&#39;s RAV4 2023 Will Sho...
# 354  TÆ° Lá»nh TQLC Nga á» Kherson cÃ³ thá» ÄÃ£...
# 391  DANCED IN THE RAIN ð§ï¸ #foryou #rain #murd...
#
#                    Channel ID     Views   Likes  Dislikes  Comments  \
# 0    UCfDpWxtKc_PBOXr7gPLXLrQ  24928443      32         0         5
# 1    UCrzyJYtjLOTfnUur8hsr7ow  22639285  120531         0      7473
# 2    UCrzyJYtjLOTfnUur8hsr7ow  16144028  125884         0      6735
# 3    UCNR1KcWXj7zpWQFJtU3ddYg  11888301   92724         0      3836
# 4    UCUbw50S9E4dRDq8whoUGtsA   8537098   85433         0      2488
# ..                        ...       ...     ...       ...       ...
# 296  UC4OdfHtdQf7LSVigj-v0Beg    585030      30         0         3
# 325  UCJ5hYPQ2x3un_jjtM6egPrQ    320448      66         0         1
# 346  UCqFYonMui0nemny21XPhIgg    222000    1759         0       108
# 354  UCdioDuMh5_afhGJTAkbQjdQ    203657       0         0         0
# 391  UC34Rt4YFAwwOz-7oXJ07Z8w    252916   46756         0      1367
#
#         Time of Uploading               Category  Views (Millions)  \
# 0    2023-05-16T03:21:41Z         People & Blogs         24.928443
# 1    2017-01-13T01:37:07Z       Film & Animation         22.639285
# 2    2016-09-09T16:55:30Z       Film & Animation         16.144028
# 3    2016-06-15T18:15:01Z       Film & Animation         11.888301
# 4    2023-06-17T23:00:24Z         People & Blogs          8.537098
# ..                    ...                    ...               ...
# 296  2021-12-08T16:39:14Z        Travel & Events          0.585030
# 325  2019-08-05T14:32:06Z       Autos & Vehicles          0.320448
# 346  2022-06-25T19:15:00Z       Autos & Vehicles          0.222000
# 354  2023-02-03T21:00:22Z  Nonprofits & Activism          0.203657
# 391  2023-08-03T03:53:14Z                 Comedy          0.252916
#
#      Likes (Thousands)  Comments (Thousands)
# 0                0.032                 0.005
# 1              120.531                 7.473
# 2              125.884                 6.735
# 3               92.724                 3.836
# 4               85.433                 2.488
# ..                 ...                   ...
# 296              0.030                 0.003
# 325              0.066                 0.001
# 346              1.759                 0.108
# 354              0.000                 0.000
# 391             46.756                 1.367
#
# [67 rows x 11 columns]

# %%
category_totals = file.groupby("Category")[["Views", "Likes", "Dislikes", "Comments"]].sum()
category_totals
# Out:
#                           Views   Likes  Dislikes  Comments
# Category
# Autos & Vehicles        1272487   51974         0      2634
# Comedy                  2533345  192169         0      2517
# Education               2993008   43728         0      3769
# Entertainment          44663079  962347         0     54182
# Film & Animation       72575888  726717         0     24568
# Gaming                 18019125  875244         0     40979
# Howto & Style          20818769  296716         0     20916
# Music                  10384719  181536         0     24787
# News & Politics        16076125  332988         0     50538
# Nonprofits & Activism    203657       0         0         0
# People & Blogs         91059866  532581         0     26037
# Pets & Animals           490751     606         0         9
# Science & Technology   13600025   58969         0      4038
# Sports                 10444455  293477         0     19915
# Travel & Events         2157670  158651         0      7559

# %%
# Convert Views and Likes columns to millions
category_totals["Views (Millions)"] = category_totals["Views"] * million_factor
category_totals["Likes (Millions)"] = category_totals["Likes"] * million_factor
# Sample data
x = category_totals["Likes (Millions)"]
y = category_totals["Views (Millions)"]
# Perform linear regression
slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)
#Create Scatter Plots
plt.scatter(x, y, marker="o", color="blue", edgecolors = "black" )
plt.xlabel("Amount of Likes(millions)")
plt.ylabel("Amount of Views(millions)")
plt.title("Category Likes vs. Views")
# Plot the regression line
regression_line = slope * x + intercept
plt.plot(x, regression_line, color="red", label="Regression Line")
# Display the linear regression equation and correlation coefficient on the plot
equation = f"y = {slope:.2f}x + {intercept:.2f}"
correlation = f"Correlation: {r_value:.2f}"
plt.text(0.1, 0.9, equation, transform=plt.gca().transAxes)
plt.text(0.1, 0.85, correlation, transform=plt.gca().transAxes)
plt.savefig("output/4.png")
plt.show()

# %%
# Convert Likes and Comments columns to desired units
category_totals["Comments (Thousands)"] = category_totals["Comments"] * thousand_factor
# Sample data
x = category_totals["Likes (Millions)"]
y = category_totals["Comments (Thousands)"]
# Perform linear regression
slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)
#Create Scatter Plots
plt.scatter(x, y, marker="o", color="blue", edgecolors = "black" )
plt.xlabel("Amount of Likes(million)")
plt.ylabel("Amount of Comments(thousand)")
plt.title("Category Likes vs. Comments")
# Plot the regression line
regression_line = slope * x + intercept
plt.plot(x, regression_line, color="red", label="Regression Line")
# Display the linear regression equation and correlation coefficient on the plot
equation = f"y = {slope:.2f}x + {intercept:.2f}"
correlation = f"Correlation: {r_value:.2f}"
plt.text(0.1, 0.9, equation, transform=plt.gca().transAxes)
plt.text(0.1, 0.85, correlation, transform=plt.gca().transAxes)
plt.savefig("output/5.png")
plt.show()

# %%
# Sample data
x = category_totals["Views (Millions)"]
y = category_totals["Comments (Thousands)"]

# Perform linear regression
slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)
#Create Scatter Plots
plt.scatter(x, y, marker="o", color="blue", edgecolors = "black" )
plt.xlabel("Amount of Views(million)")
plt.ylabel("Amount of Comments(thousand)")
plt.title("Category Views vs. Comments")
# Plot the regression line
regression_line = slope * x + intercept
plt.plot(x, regression_line, color="red", label="Regression Line")
# Display the linear regression equation and correlation coefficient on the plot
equation = f"y = {slope:.2f}x + {intercept:.2f}"
correlation = f"Correlation: {r_value:.2f}"
plt.text(0.1, 0.9, equation, transform=plt.gca().transAxes)
plt.text(0.1, 0.85, correlation, transform=plt.gca().transAxes)
plt.savefig("output/6.png")
plt.show()
